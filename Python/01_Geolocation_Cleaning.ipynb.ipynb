# %%
from prophet import Prophet

print("Prophet Installed Successfully")
# Out:
# Prophet Installed Successfully

# %%
import pandas as pd

geo = pd.read_csv('olist_geolocation_dataset.csv')

geo = geo.drop_duplicates(
    subset='geolocation_zip_code_prefix'
)

geo.to_csv(
    'olist_geolocation_clean.csv',
    index=False
)

# %%
import pandas as pd

geo = pd.read_csv('olist_geolocation_clean.csv')

print("Rows after cleaning:", len(geo))
print("Unique ZIP codes:", geo['geolocation_zip_code_prefix'].nunique())
# Out:
# Rows after cleaning: 19015
# Unique ZIP codes: 19015
